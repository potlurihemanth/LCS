# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import genfromtxt
import pandas as pd

# %%
fr1 = genfromtxt("/home/gramx/Desktop/cosmology_codes/Results/ClusterStat_R2_original.txt")
#file_1=np.array(file)
z_cc = fr1[1:,0]
Nc_cc = fr1[1:,1]
ff_cc = fr1[1:,2]
lcs_cc = fr1[1:,3]
xn_cc = fr1[1:,4]
print(Nc_cc)
# Out:
# [ 20918.  57352. 166216. 218525. 254116. 264052. 256508. 224345. 210321.
#  187789. 137565. 114028.  87491.  78931.]

# %%
freq_cc=np.array([])
for i in range(len(z_cc)):
    freq=1422.8/(1+z_cc[i])
    freq_cc=np.append(freq_cc,freq)
print(freq_cc)
# Out:
# [126.02302923 132.09544146 139.98425817 145.74882196 149.53231739
#  153.26941721 155.12429132 160.60503443 162.42009132 164.21975993
#  167.78301887 169.56262662 171.31848284 173.06896971]

# %%
fr2 = genfromtxt("/home/gramx/Desktop/cosmology_codes/Results/lcs_10.txt",delimiter=',')
#file_1=np.array(file)
xn_10 = fr2[1:,0]
ff_10= fr2[1:,1]
lcs_10 = fr2[1:,2]
z_10 = fr2[1:,3]
print(lcs_10)
# Out:
# [0.98035547 0.97193357 0.94578479 0.23150645 0.18838829 0.07957469
#  0.05974212 0.05386337 0.05169021 0.0293121  0.02231465 0.01989998
#  0.01844926 0.01605996 0.02608696 0.03169014]

# %%
fr3 = genfromtxt("/home/gramx/Desktop/cosmology_codes/Results/lcs_20.txt",delimiter=',')
#file_1=np.array(file)
z_20 = fr3[1:,0]
xn_20= fr3[1:,1]
ff_20 = fr3[1:,2]
lcs_20 = fr3[1:,3]
print(lcs_20)
# Out:
# [0.9852683  0.95853199 0.17618259 0.05726928 0.03995268 0.02231465
#  0.02231465 0.01844926 0.01605996 0.02608696]

# %%
fr4 = genfromtxt("/home/gramx/Desktop/cosmology_codes/Results/overlap_20_10.txt",delimiter=' ')
#file_1=np.array(file)
z_ol20 = fr4[1:,0]
xn_ol20= fr4[1:,1]
lcs_ol20 = fr4[1:,2]
ff_ol20 = fr4[1:,3]
print(lcs_ol20)
# Out:
# [0.9852683  0.97533283 0.95853199 0.56148222 0.17618259 0.09236998
#  0.05726928 0.03105227 0.03995268 0.02964711 0.01740846 0.01578121
#  0.01427469 0.01293103 0.02197802 0.03370787 0.11428571 0.125
#         nan]

# %%
fr5 = genfromtxt("/home/gramx/Desktop/cosmology_codes/Results/overlap_10_5.txt",delimiter=' ')
#file_1=np.array(file)
z_ol10 = fr5[:,0]
xn_ol10= fr5[:,1]
lcs_ol10 = fr5[:,2]
ff_ol10 = fr5[:,3]
print(z_ol10)
# Out:
# [ 7.29916041  7.34405055  7.3893042   7.4349253   7.48091786  7.52728595
#   7.57403368  7.62116522  7.6686848   7.71659673  7.76490534  7.81361505
#   7.86273033  7.91225571  7.96219577  8.01255516  8.0633386   8.11455089
#   8.16619691  8.2182816   8.32446798  8.43180491  8.54099999  8.65209639
#   8.76513867  8.88017271  8.99724567  9.11640621  9.23770425  9.36119151
#   9.55209675  9.81294464 10.083565   10.36445303 10.65613568 10.95917484]

# %%
fr6 = genfromtxt("/home/gramx/Desktop/cosmology_codes/Results/overlap_40_20.txt",delimiter=' ')
#file_1=np.array(file)
z_ol40 = fr6[:,0]
xn_ol40= fr6[:,1]
lcs_ol40 = fr6[:,2]
ff_ol40 = fr6[:,3]
print(z_ol40)
# Out:
# [ 7.34459579  7.53013361  7.71957226  7.91536621  8.11780428  8.32719183
#   8.54385167  8.76812595  9.00037666  9.24098756  9.49036648  9.74894534
#  10.01718389 10.29557032 10.58462371 10.88489804]

# %%
fr7 = genfromtxt("/home/gramx/Desktop/cosmology_codes/Results/overlap_60_30.txt",delimiter=' ')
#file_1=np.array(file)
z_ol60 = fr7[:,0]
xn_ol60= fr7[:,1]
lcs_ol60 = fr7[:,2]
ff_ol60 = fr7[:,3]
print(z_ol60)
# Out:
# [ 7.34459579  7.72354137  8.01997929  8.33173349  8.65988123  9.00559725
#   9.37016253  9.75497697 10.16157281 10.59162947 10.95705267 11.18422911]

# %%
fr8 = genfromtxt("/home/gramx/Desktop/cosmology_codes/Results/overlap_80_40.txt",delimiter=' ')
#file_1=np.array(file)
z_ol80 = fr8[:,0]
xn_ol80= fr8[:,1]
lcs_ol80 = fr8[:,2]
ff_ol80 = fr8[:,3]
print(z_ol80)
# Out:
# [ 7.34459579  7.82639968  8.23226804  8.66669879  9.13244763  9.63261052
#  10.17067393 10.74248288 11.03132947]

# %%
fr9 = genfromtxt("/home/gramx/Desktop/cosmology_codes/Results/overlap_100_50.txt",delimiter=' ')
#file_1=np.array(file)
z_ol100 = fr9[:,0]
xn_ol100= fr9[:,1]
lcs_ol100 = fr9[:,2]
ff_ol100 = fr9[:,3]
print(z_ol100)
# Out:
# [ 7.34459579  7.93280788  8.45412532  9.02232382  9.64322362 10.32357357
#  10.81266375 11.18422911]

# %%
fr10 = genfromtxt("/home/gramx/Desktop/cosmology_codes/Results/frequency_3Mhz.txt",delimiter=' ')
#file_1=np.array(file)
z_f3 = fr10[:,0]
xn_f3= fr10[:,1]
freq_f3=fr10[:,2]
lcs_f3 = fr10[:,3]
ff_f3 = fr10[:,4]
print(freq_f3)
# Out:
# [170.80049571 167.68087831 164.59039067 161.52900508 158.49669606
#  155.40598876 152.25861193 149.1437465  146.06137073 143.01146069
#  139.99399319 136.92695578 133.81217229 130.73346116 127.69080486
#  124.60603351 121.48107496]

# %%
fr11 = genfromtxt("/home/gramx/Desktop/cosmology_codes/Results/frequency_5Mhz.txt",delimiter=' ')
#file_1=np.array(file)
z_f5 = fr11[:,0]
xn_f5= fr11[:,1]
freq_f5=fr11[:,2]
lcs_f5 = fr11[:,3]
ff_f5 = fr11[:,4]
print(freq_f5)
# Out:
# [169.79425889 164.68710261 159.57054277 154.4473275  149.32316255
#  144.20089181 139.08642432 133.98270274 128.89582184 123.82883521]

# %%
fr12 = genfromtxt("/home/gramx/Desktop/cosmology_codes/Results/frequency_7Mhz.txt",delimiter=' ')
#file_1=np.array(file)
z_f7 = fr12[:,0]
xn_f7= fr12[:,1]
freq_f7=fr12[:,2]
lcs_f7 = fr12[:,3]
ff_f7 = fr12[:,4]
print(freq_f7)
# Out:
# [168.79411963 161.63511814 154.54446886 147.52989315 140.51266759
#  133.42468903 126.28288087]

# %%
fr13= genfromtxt("/home/gramx/Desktop/cosmology_codes/Results/frequency_ol_7Mhz.txt",delimiter=' ')
#file_1=np.array(file)
z_of7 = fr13[:,0]
xn_of7= fr13[:,1]
freq_of7=fr13[:,2]
lcs_of7 = fr13[:,3]
ff_of7 = fr13[:,4]
print(freq_f7)
# Out:
# [168.79411963 161.63511814 154.54446886 147.52989315 140.51266759
#  133.42468903 126.28288087]

# %%
plt.xlabel("Neutral fraction")
plt.ylabel("Largest Cluster Statistics")
plt.plot(xn_10,lcs_10,color='g',label='10 pixel')
plt.plot(xn_20,lcs_20,color='r',label='20 pixel')
plt.plot(xn_ol40[:12],lcs_ol40[:12],color='Orange',label='40 pixel')
plt.plot(xn_cc,lcs_cc,color='b',label='Coeval cube')
plt.axvline(0.52726156, color="Black", linestyle="dotted")
plt.axvline(0.405782, color="Black", linestyle="dotted")
plt.axvline(0.750264, color="Black", linestyle="dotted")
plt.axvline(0.6285098206498531681, color="Black", linestyle="dotted")
plt.legend()

# %%
fig,ax = plt.subplots(figsize=(10,6))
plt.xlabel("Red shift")
plt.ylabel("Largest Cluster Statistics")
plt.plot(z_10,lcs_10,color='g',label='10 pixel',linestyle="dotted")
plt.plot(z_20,lcs_20,color='r',label='20 pixel',linestyle="dotted")
plt.plot(z_ol40[:12],lcs_ol40[:12],color='Orange',label='40 pixel',linestyle="dotted")
plt.plot(z_ol60[:9],lcs_ol60[:9],color='Purple',label='60 pixel',linestyle="dotted")
plt.plot(z_ol80[:7],lcs_ol80[:7],color='Cyan',label='80 pixel',linestyle="dotted")
plt.plot(z_ol100[:6],lcs_ol100[:6],color='Brown',label='100 pixel',linestyle="dotted")
plt.plot(z_cc,lcs_cc,color='b',label='Coeval cube',linestyle="dotted")
plt.axvline(7.57403368, color="Black", linestyle="dotted")
plt.axvline(7.71719175, color="Black", linestyle="dotted")
plt.axvline(7.915366211, color="Black", linestyle="dotted")
plt.axvline(7.915366211993676515, color="Black", linestyle="dotted")
plt.axvline(8.283, color="Black", linestyle="dotted")
plt.axvline(8.019979291296872148, color="Black", linestyle="dotted")
plt.axvline(8.232268039953559935, color="Black", linestyle="dotted")
plt.axvline(8.454125316431035486, color="Black", linestyle="dotted")
#7.915366211993676515e+00
plt.legend()

# %%
fig,ax = plt.subplots(figsize=(10,6))
plt.xlabel("Frequency(Mhz)")
plt.ylabel("Largest Cluster Statistics")
plt.plot(freq_f3[:13],lcs_f3[:13],color='g',label='3 Mhz',linestyle="dotted")
plt.plot(freq_f5[:9],lcs_f5[:9],color='brown',label='5 Mhz',linestyle="dotted")
plt.plot(freq_f7[:6],lcs_f7[:6],color='r',label='7 Mhz',linestyle="dotted")
plt.plot(freq_cc,lcs_cc,color='b',label='Coeval',linestyle="dotted")

plt.gca().invert_xaxis()
plt.legend()

# %%
plt.xlabel("Neutral fraction")
plt.ylabel("Largest Cluster Statistics")
plt.plot(xn_ol20[:15],lcs_ol20[:15],color='g',label='overlap_20',linestyle="dotted")
plt.plot(xn_20,lcs_20,color='r',label='20 pixel')
plt.plot(xn_cc,lcs_cc,color='b',label='Coeval cube')
plt.axvline(0.52726156, color="Black", linestyle="dotted")
plt.axvline(0.750264, color="Black", linestyle="dotted")
plt.legend()

# %%
fig,ax = plt.subplots(figsize=(10,6))
plt.xlabel("Red shift")
plt.ylabel("Largest Cluster Statistics")
plt.plot(z_ol20[:15],lcs_ol20[:15],color='g',label='overlap_20',linestyle="dotted")
plt.plot(z_20,lcs_20,color='r',label='20 pixel')
plt.plot(z_cc,lcs_cc,color='b',label='Coeval cube')
plt.axvline(7.71719175, color="Black", linestyle="dotted")
plt.axvline(8.283, color="Black", linestyle="dotted")
plt.legend()

# %%
fig,ax = plt.subplots(figsize=(10,6))
plt.xlabel("Red shift")
plt.ylabel("Largest Cluster Statistics")
plt.plot(z_ol10[:30],lcs_ol10[:30],color='g',label='overlap_10',linestyle="dotted")
plt.plot(z_10,lcs_10,color='r',label='10 pixel')
plt.plot(z_cc,lcs_cc,color='b',label='Coeval cube')
plt.axvline(7.57403368, color="Black", linestyle="dotted")
plt.axvline(8.283, color="Black", linestyle="dotted")
plt.legend()

# %%
pc_array=[7.574033675685315714,7.621747267217228838,7.915366211993676515,8.019979291296872148,8.232268039953559935,8.454125316431035486]
ch_size=[10,20,40,60,80,100]

# %%
fig,ax = plt.subplots(figsize=(10,6))
plt.xlabel("Red shift")
plt.ylabel("Chunk Size")
plt.scatter(pc_array,ch_size,color='r')
plt.axvline(8.283, color="Black", linestyle="dotted")
plt.legend()
np.corrcoef(pc_array,ch_size)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# array([[1.        , 0.99444741],
#        [0.99444741, 1.        ]])

# %%
fig,ax = plt.subplots(figsize=(10,6))
plt.xlabel("Frequency")
plt.ylabel("Largest Cluster Statistics")
plt.plot(freq_of7[:11],lcs_of7[:11],color='g',label='overlap_7Mhz',linestyle="dotted")
plt.plot(freq_f7[:8],lcs_f7[:8],color='r',label='7 Mhz',linestyle="dotted")
plt.plot(freq_cc,lcs_cc,color='b',label='Coeval cube')
#plt.axvline(7.57403368, color="Black", linestyle="dotted")
#plt.axvline(8.283, color="Black", linestyle="dotted")
plt.gca().invert_xaxis()
plt.legend()
